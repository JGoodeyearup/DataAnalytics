# %% [markdown]
# # Lab 3 Employee Data
# This lab makes updates to information extracted from an employee database.

# %%
hr_list = [
('0123', 'HR', 'Rebecca Yang', '69000'),
('0121', 'IT', 'Mark Blick', '67000'),
('0068', 'IT', 'Kahna Larsen', '112000'),
('0234', 'OPS', 'Jim Smith', '54000')
]

# %%
for i in range(len(hr_list)):
    if hr_list[i][2] == 'Mark Blick':
        hr_list[i] = (hr_list[i][0], hr_list[i][1], 'Mark Blick-Hawley', hr_list[i][3])

# %%
parse_and_display(hr_list)
print(hr_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 parse_and_display(hr_list)
#       2 print(hr_list)
#
# NameError: name 'parse_and_display' is not defined

# %%
for i in range(len(hr_list)):
    if hr_list[i][2] == 'Jim Smith':
        hr_list[i] = (hr_list[i][0], 'CS', hr_list[i][2], '60000')

# %%
print(hr_list)
# Out:
# [('0123', 'HR', 'Rebecca Yang', '69000'), ('0121', 'IT', 'Mark Blick-Hawley', '67000'), ('0068', 'IT', 'Kahna Larsen', '112000'), ('0234', 'CS', 'Jim Smith', '60000')]

# %%
parse_and_display(hr_list)
for item in hr_list:
    print(f"{hr_list[i][0]} | {hr_list[i][1]} | {hr_list[i][2]} | {hr_list[i][3]}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 parse_and_display(hr_list)
#       2 for item in hr_list:
#       3     print(f"{hr_list[i][0]} | {hr_list[i][1]} | {hr_list[i][2]} | {hr_list[i][3]}")
#
# NameError: name 'parse_and_display' is not defined
